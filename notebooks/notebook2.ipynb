# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Clinical-Informatics-Interest-Group/CLiC.notebooks/blob/main/notebooks/notebook2.ipynb)

# %% [markdown]
# # 2. Machine Learning
#
# This notebook fits a Random Forest Classifier to our data and attempts to answer the following questions:
#
# * [Can we predict hospital readmissions?](#Random-Forest-Classifier)
# * [What are the important factors contributing most to a patient’s readmission?](#The-Most-Important-Features)
# * What is the impact of ommitting data that was not fully collected? Is there a pattern?
# * [How will including race or gender in our machine learning model affect outcomes?](#How-Gender-or-Race-Affects-Predictions)
#
# A Random Forest Classifier is an ensemble of Decision Trees which predict the outcome by a majority vote. A complete explanation is beyond the scope of this notebook, as our goal is to get an idea of how machine learning algorithms may be applied in healthcare and its ethical implications.
#
# [Getting the data into shape](#Getting-the-data-into-shape)

# %%
import pandas as pd
import numpy as np
import zipfile, requests, io
from pathlib import Path

# %%
def get_data():
    if Path('./dataset_diabetes/diabetic_data.csv').is_file():
        pass
    else:
        r = requests.get('https://archive.ics.uci.edu/ml/machine-learning-databases/00296/dataset_diabetes.zip')
        z = zipfile.ZipFile(io.BytesIO(r.content))
        z.extractall()
        
get_data()

# %%
df = pd.read_csv('./dataset_diabetes/diabetic_data.csv', na_values=['?'])
df.head()
# Out:
# /home/justin/anaconda3/envs/dsmed/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)    NaN
# 1        149190     55629189        Caucasian  Female  [10-20)    NaN
# 2         64410     86047875  AfricanAmerican  Female  [20-30)    NaN
# 3        500364     82442376        Caucasian    Male  [30-40)    NaN
# 4         16680     42519267        Caucasian    Male  [40-50)    NaN
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# 0                 1  ...          No      No                   No
# 1                 3  ...          No      Up                   No
# 2                 2  ...          No      No                   No
# 3                 2  ...          No      Up                   No
# 4                 1  ...          No  Steady                   No
#
#    glipizide-metformin  glimepiride-pioglitazone  metformin-rosiglitazone  \
# 0                   No                        No                       No
# 1                   No                        No                       No
# 2                   No                        No                       No
# 3                   No                        No                       No
# 4                   No                        No                       No
#
#    metformin-pioglitazone  change diabetesMed readmitted
# 0                      No      No          No         NO
# 1                      No      Ch         Yes        >30
# 2                      No      No         Yes         NO
# 3                      No      Ch         Yes         NO
# 4                      No      Ch         Yes         NO
#
# [5 rows x 50 columns]

# %% [markdown]
# ## Getting the data into shape
# Before we can train the model, we want to make sure the dataset is free of missing values and the features we include are relevant to our research question.
#
# #### These columns contain unique identifiers we don't want the model to train on.
# * encounter_id
# * patient_nbr
#
# #### These feature columns contain only 'No' values, so should be dropped.
# * citoglipton
# * examide
#
# #### These feature columns contain too many null values and will be dropped.
# * weight
#
# #### These feature columns are missing in about half the data. We will drop these, but come back to them later.
# * payer_code
# * medical_specialty

# %%
# There's probably a more programatical and pythonic way to do this, but this is all I know...
df.pop('citoglipton')
df.pop('examide')
df.pop('weight')
df.pop('payer_code')
df.pop('medical_specialty')
df.pop('encounter_id')
df.pop('patient_nbr')
df.head()
# Out:
#               race  gender      age  admission_type_id  \
# 0        Caucasian  Female   [0-10)                  6
# 1        Caucasian  Female  [10-20)                  1
# 2  AfricanAmerican  Female  [20-30)                  1
# 3        Caucasian    Male  [30-40)                  1
# 4        Caucasian    Male  [40-50)                  1
#
#    discharge_disposition_id  admission_source_id  time_in_hospital  \
# 0                        25                    1                 1
# 1                         1                    7                 3
# 2                         1                    7                 2
# 3                         1                    7                 2
# 4                         1                    7                 1
#
#    num_lab_procedures  num_procedures  num_medications  ...  tolazamide  \
# 0                  41               0                1  ...          No
# 1                  59               0               18  ...          No
# 2                  11               5               13  ...          No
# 3                  44               1               16  ...          No
# 4                  51               0                8  ...          No
#
#    insulin  glyburide-metformin glipizide-metformin glimepiride-pioglitazone  \
# 0       No                   No                  No                       No
# 1       Up                   No                  No                       No
# 2       No                   No                  No                       No
# 3       Up                   No                  No                       No
# 4   Steady                   No                  No                       No
#
#   metformin-rosiglitazone  metformin-pioglitazone change diabetesMed  \
# 0                      No                      No     No          No
# 1                      No                      No     Ch         Yes
# 2                      No                      No     No         Yes
# 3                      No                      No     Ch         Yes
# 4                      No                      No     Ch         Yes
#
#   readmitted
# 0         NO
# 1        >30
# 2         NO
# 3         NO
# 4         NO
#
# [5 rows x 43 columns]

# %%
# Which features contain null values?
df.isnull().sum()
# Out:
# race                        2273
# gender                         0
# age                            0
# admission_type_id              0
# discharge_disposition_id       0
# admission_source_id            0
# time_in_hospital               0
# num_lab_procedures             0
# num_procedures                 0
# num_medications                0
# number_outpatient              0
# number_emergency               0
# number_inpatient               0
# diag_1                        21
# diag_2                       358
# diag_3                      1423
# number_diagnoses               0
# max_glu_serum                  0
# A1Cresult                      0
# metformin                      0
# repaglinide                    0
# nateglinide                    0
# chlorpropamide                 0
# glimepiride                    0
# acetohexamide                  0
# glipizide                      0
# glyburide                      0
# tolbutamide                    0
# pioglitazone                   0
# rosiglitazone                  0
# acarbose                       0
# miglitol                       0
# troglitazone                   0
# tolazamide                     0
# insulin                        0
# glyburide-metformin            0
# glipizide-metformin            0
# glimepiride-pioglitazone       0
# metformin-rosiglitazone        0
# metformin-pioglitazone         0
# change                         0
# diabetesMed                    0
# readmitted                     0
# dtype: int64

# %%
# Drop the samples that contain null values
df = df.dropna(axis=0)
df.isnull().sum()
# Out:
# race                        0
# gender                      0
# age                         0
# admission_type_id           0
# discharge_disposition_id    0
# admission_source_id         0
# time_in_hospital            0
# num_lab_procedures          0
# num_procedures              0
# num_medications             0
# number_outpatient           0
# number_emergency            0
# number_inpatient            0
# diag_1                      0
# diag_2                      0
# diag_3                      0
# number_diagnoses            0
# max_glu_serum               0
# A1Cresult                   0
# metformin                   0
# repaglinide                 0
# nateglinide                 0
# chlorpropamide              0
# glimepiride                 0
# acetohexamide               0
# glipizide                   0
# glyburide                   0
# tolbutamide                 0
# pioglitazone                0
# rosiglitazone               0
# acarbose                    0
# miglitol                    0
# troglitazone                0
# tolazamide                  0
# insulin                     0
# glyburide-metformin         0
# glipizide-metformin         0
# glimepiride-pioglitazone    0
# metformin-rosiglitazone     0
# metformin-pioglitazone      0
# change                      0
# diabetesMed                 0
# readmitted                  0
# dtype: int64

# %%
# Now that we removed all samples and features missing data
# let's verify each data type matches our assessment of
# which variables are categorical (objects or strings) versus nominal (integers)
df.dtypes
# Out:
# race                        object
# gender                      object
# age                         object
# admission_type_id            int64
# discharge_disposition_id     int64
# admission_source_id          int64
# time_in_hospital             int64
# num_lab_procedures           int64
# num_procedures               int64
# num_medications              int64
# number_outpatient            int64
# number_emergency             int64
# number_inpatient             int64
# diag_1                      object
# diag_2                      object
# diag_3                      object
# number_diagnoses             int64
# max_glu_serum               object
# A1Cresult                   object
# metformin                   object
# repaglinide                 object
# nateglinide                 object
# chlorpropamide              object
# glimepiride                 object
# acetohexamide               object
# glipizide                   object
# glyburide                   object
# tolbutamide                 object
# pioglitazone                object
# rosiglitazone               object
# acarbose                    object
# miglitol                    object
# troglitazone                object
# tolazamide                  object
# insulin                     object
# glyburide-metformin         object
# glipizide-metformin         object
# glimepiride-pioglitazone    object
# metformin-rosiglitazone     object
# metformin-pioglitazone      object
# change                      object
# diabetesMed                 object
# readmitted                  object
# dtype: object

# %%
# Age is considered nominal and the authors list it by decade,
# although I think this makes it numerical. We'll just leave it for now...
#np.unique(df["age"])

# %%
# To simplify our problem, let's make the outcome binary.
# We are going to ask our model to predict whether patients
# discharged from the hospital are readmitted within 30 days.
df = df.replace({'readmitted': {'>30': 0,  'NO': 0, '<30': 1}})
np.unique(df["readmitted"])
# Out:
# array([0, 1])

# %% [markdown]
# ## Random Forest Classifier

# %%
### Our first machine learning model will be a Random Forest classifier ###
# Python best practices would have us import all the libraries we need at the
# beginning. For clarity I am importing libraries as we use them so it's
# easier to see where they'll be used.

from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split

# The model is defined here. We'll use the "fit" method to train it with
# a training "X" subset of the overall data. Then we'll "predict" outcomes
# and verify its performance against a "test" subset.
rforest = RandomForestClassifier(criterion='gini',
                                n_estimators=25,
                                random_state=1)

# "X" DataFrame for all the features of each sample
# The get_dummies method makes sure the categorical features are not treated
# as continuous variables.
X = pd.get_dummies(df.iloc[:, :42], drop_first=True)
# "y" DataFrame for the target outcome "readmitted"
y = df.readmitted
# Split "X" and "y" equivalently so that 80% of the samples
# are used to train the model, and 20% are reserved for testing
# its performance
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, stratify=y, random_state=1)
# Train the model
rforest.fit(X_train, y_train)
# Test it
y_pred = rforest.predict(X_test)
print('Test Accuracy: %.3f' % rforest.score(X_test, y_test))
# Out:
# Test Accuracy: 0.888

# %% [markdown]
# ## Progress Summary
# Up to this point we have implemented a Machine Learning model to predict hospital readmissions. We have left out a few Machine Learning best practices to demonstrate how easy this is to do. As we make progress in the Hackathon we hope to gain an appreciation for how best practices can help us to make better and more representative models. A machine learning model can perform well against an arbitrary metric, but not be representative of the data or people who make up that data in the real world.

# %% [markdown]
# ## The Most Important Features

# %%
# Here we will print the 30 most important features
# as the model has assigned them.
importances = rforest.feature_importances_

indices = np.argsort(importances)[::-1]

for f in range(30):
    print("%2d) %-*s %f" % (f + 1, 30, 
                            X.columns[:][indices[f]], 
                            importances[indices[f]]))
# Out:
#  1) num_lab_procedures             0.052039
#  2) num_medications                0.049527
#  3) time_in_hospital               0.038417
#  4) number_inpatient               0.034222
#  5) num_procedures                 0.027331
#  6) discharge_disposition_id       0.027323
#  7) number_diagnoses               0.025209
#  8) admission_type_id              0.020720
#  9) admission_source_id            0.017738
# 10) gender_Male                    0.015203
# 11) number_outpatient              0.014540
# 12) number_emergency               0.012454
# 13) race_Caucasian                 0.011930
# 14) age_[70-80)                    0.011048
# 15) insulin_Steady                 0.010883
# 16) change_No                      0.010526
# 17) age_[60-70)                    0.010441
# 18) insulin_No                     0.009202
# 19) age_[80-90)                    0.008511
# 20) A1Cresult_None                 0.007199
# 21) age_[50-60)                    0.006771
# 22) insulin_Up                     0.006302
# 23) glipizide_No                   0.006287
# 24) glipizide_Steady               0.005917
# 25) glyburide_No                   0.005616
# 26) diag_2_428                     0.005609
# 27) diabetesMed_Yes                0.005530
# 28) metformin_Steady               0.005490
# 29) diag_2_276                     0.005482
# 30) metformin_No                   0.005453

# %% [markdown]
# ## How Gender or Race Affects Predictions

# %%
# Since the original feature columns were expanded with the
# get_dummies method, we need to find which columns include
# race data.

import re # A library for working with regular expressions

for col in X_test.columns:
    if re.search("race*", col) == None:
        pass
    else:
        print(col)
# Out:
# race_Asian
# race_Caucasian
# race_Hispanic
# race_Other

# %%
# Make an empty array to fill with all the indices that are not the specified race
not_Asian = np.array([])
not_Caucasian = np.array([])
not_Hispanic = np.array([])
not_Other = np.array([])

# Fill the empty arrays with the indices as described.
for index in X_test.index:
    if X_test.race_Asian[index] == 1:
        pass
    else:
        not_Asian = np.append(not_Asian, [index])

not_Asian
# Out:
# array([32840., 78785., 79780., ..., 99297., 74754., 39823.])

# %%
# Create a test set with only sample data identified as Asian
X_test_Asian = X_test.drop(not_Asian)
X_test_Asian.race_Asian.cumsum(axis=0)
# Out:
# 87359       1
# 97459       2
# 78832       3
# 94853       4
# 101461      5
#          ...
# 95363     140
# 26825     141
# 2193      142
# 86498     143
# 72611     144
# Name: race_Asian, Length: 144, dtype: uint64

# %%
y_test_Asian = y_test.drop(not_Asian)

# %%
y_pred_Asian = rforest.predict(X_test_Asian)
print('Test Accuracy: %.3f' % rforest.score(X_test_Asian, y_test_Asian))
# Out:
# Test Accuracy: 0.875

# %%
# 
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[17393,     5],
#        [ 2199,    14]])
